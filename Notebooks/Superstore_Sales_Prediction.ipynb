# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('SampleSuperstore.csv', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
sns.heatmap(df.isnull(),yticklabels=False)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 1.6+ MB

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.barplot(x='Region',y='Sales',data=df)
# Out:
# <Axes: xlabel='Region', ylabel='Sales'>

# %%
region_sales = df.groupby('Region')['Sales'].sum().reset_index()

sns.barplot(data=region_sales, x='Region', y='Sales', palette='viridis')
# Out:
# C:\Users\Z30\AppData\Local\Temp\ipykernel_6712\2177857313.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=region_sales, x='Region', y='Sales', palette='viridis')
# <Axes: xlabel='Region', ylabel='Sales'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 1.6+ MB

# %%
df.drop(['Row ID','Order ID','Customer ID','Customer Name','Product Name'],axis=1,inplace=True)

# %%
Q1 = df['Sales'].quantile(0.25)
Q3 = df['Sales'].quantile(0.75)
IQR = Q3-Q1
lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

df = df[(df['Sales']>lower_bound)&(df['Sales']<upper_bound)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8827 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order Date    8827 non-null   datetime64[ns]
#  1   Ship Date     8827 non-null   datetime64[ns]
#  2   Ship Mode     8827 non-null   object
#  3   Segment       8827 non-null   object
#  4   Country       8827 non-null   object
#  5   City          8827 non-null   object
#  6   State         8827 non-null   object
#  7   Postal Code   8827 non-null   int64
#  8   Region        8827 non-null   object
#  9   Product ID    8827 non-null   object
#  10  Category      8827 non-null   object
#  11  Sub-Category  8827 non-null   object
#  12  Sales         8827 non-null   float64
#  13  Quantity      8827 non-null   int64
#  14  Discount      8827 non-null   float64
#  15  Profit        8827 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(9)
# memory usage: 1.1+ MB

# %%
df.drop(['Ship Date'],axis=1,inplace=True)

# %%
df['Order Year'] = df['Order Date'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8827 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order Date    8827 non-null   datetime64[ns]
#  1   Ship Mode     8827 non-null   object
#  2   Segment       8827 non-null   object
#  3   Country       8827 non-null   object
#  4   City          8827 non-null   object
#  5   State         8827 non-null   object
#  6   Postal Code   8827 non-null   int64
#  7   Region        8827 non-null   object
#  8   Product ID    8827 non-null   object
#  9   Category      8827 non-null   object
#  10  Sub-Category  8827 non-null   object
#  11  Sales         8827 non-null   float64
#  12  Quantity      8827 non-null   int64
#  13  Discount      8827 non-null   float64
#  14  Profit        8827 non-null   float64
#  15  Order Year    8827 non-null   int32
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(2), object(9)
# memory usage: 1.1+ MB

# %%
df['Order Month'] = df['Order Date'].dt.month
df['Order Day'] = df['Order Date'].dt.day
df.drop(['Order Date'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8827 entries, 0 to 9993
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     8827 non-null   object
#  1   Segment       8827 non-null   object
#  2   Country       8827 non-null   object
#  3   City          8827 non-null   object
#  4   State         8827 non-null   object
#  5   Postal Code   8827 non-null   int64
#  6   Region        8827 non-null   object
#  7   Product ID    8827 non-null   object
#  8   Category      8827 non-null   object
#  9   Sub-Category  8827 non-null   object
#  10  Sales         8827 non-null   float64
#  11  Quantity      8827 non-null   int64
#  12  Discount      8827 non-null   float64
#  13  Profit        8827 non-null   float64
#  14  Order Year    8827 non-null   int32
#  15  Order Month   8827 non-null   int32
#  16  Order Day     8827 non-null   int32
# dtypes: float64(3), int32(3), int64(2), object(9)
# memory usage: 1.1+ MB

# %%
df_encoded = pd.get_dummies(df,drop_first=True)

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8827 entries, 0 to 9993
# Columns: 2375 entries, Postal Code to Sub-Category_Tables
# dtypes: bool(2367), float64(3), int32(3), int64(2)
# memory usage: 20.4 MB

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(df_encoded.drop('Sales',axis=1),df_encoded['Sales'],test_size=0.30,random_state=101)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Decision Tree": DecisionTreeRegressor(random_state=42),
    "Random Forest": RandomForestRegressor(random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(random_state=42)
}

results={}
predictions={}

for name,model in models.items():
    model.fit(X_train,Y_train)
    y_pred = model.predict(X_test)
    predictions[name]=y_pred
    results[name]={
        "MAE": mean_absolute_error(Y_test, y_pred),
        "RMSE": np.sqrt(mean_squared_error(Y_test, y_pred)),
        "R²": r2_score(Y_test, y_pred)
    }

df_results = pd.DataFrame(results).T

print(df_results)
# Out:
#                          MAE       RMSE        R²
# Linear Regression  40.649889  67.035964  0.671657
# Decision Tree      24.755884  55.922955  0.771497
# Random Forest      21.279289  46.228421  0.843854
# Gradient Boosting  30.283243  52.961186  0.795060

# %%
plots = plt.subplot()

for name, y_pred in predictions.items():
    plt.figure(figsize=(3, 2))
    sns.scatterplot(x=Y_test, y=y_pred)
    plt.xlabel("Actual Sales")
    plt.ylabel("Predicted Sales")
    plt.title(f"Actual vs Predicted - {name}")
    plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], 'r--')  # Perfect fit line
    plt.show()

# %%
metrics_df = pd.DataFrame(results).T.reset_index().rename(columns={'index':'Model'})

plt.figure(figsize=(8,5))
sns.barplot(x='Model', y='R²', data=metrics_df, palette='viridis')
plt.title("R² Score Comparison Across Models")
plt.ylim(0, 1)
plt.show()
# Out:
# C:\Users\Z30\AppData\Local\Temp\ipykernel_6712\1875441386.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Model', y='R²', data=metrics_df, palette='viridis')

# %%
df_results = pd.DataFrame({
    "Actual Sales": Y_test,
    "Linear Regression": predictions['Linear Regression'],
    "Decision Tree": predictions['Decision Tree'],
    "Random Forest": predictions['Random Forest'],
    "Gradient Boosting": predictions['Gradient Boosting'] 
})
df_results.head()
# Out:
#       Actual Sales  Linear Regression  Decision Tree  Random Forest  \
# 795         20.160          55.616193         20.940       20.80930
# 6955        21.340           5.461073         20.700       20.84230
# 9761       239.970         218.438193        179.970      204.58420
# 2012        46.344          45.226563         53.424       42.80018
# 4320        33.290          43.168791         31.160       32.84236
#
#       Gradient Boosting
# 795           26.305249
# 6955          24.976664
# 9761         260.635801
# 2012          67.239813
# 4320          64.916841

# %%
df_results.to_csv("SuperStore_Predictions.csv",index=False)

# %%
metrics_df = pd.DataFrame(results).T.reset_index().rename(columns={'index': 'Model'})
metrics_df.to_csv("model_metrics.csv", index=False)

# %%
print(metrics_df)
# Out:
#                Model        MAE       RMSE        R²
# 0  Linear Regression  40.649889  67.035964  0.671657
# 1      Decision Tree  24.755884  55.922955  0.771497
# 2      Random Forest  21.279289  46.228421  0.843854
# 3  Gradient Boosting  30.283243  52.961186  0.795060
